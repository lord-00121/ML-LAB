# %% [markdown]
# <a href="https://colab.research.google.com/github/lord-00121/ML-LAB/blob/main/LAB_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("stats_data.csv")

# Display first few records
print("First 5 Records:\n", df.head())

# Identify numerical & categorical columns
print("\nData Types:\n", df.dtypes)

num_cols = df.select_dtypes(include=['int64', 'float64'])
cat_cols = df.select_dtypes(include=['object'])

print("\nNumerical Columns:\n", num_cols.columns)
print("\nCategorical Columns:\n", cat_cols.columns)

# ---------------------------
# Measures of Central Tendency
# ---------------------------
print("\nMean:\n", num_cols.mean())
print("\nMedian:\n", num_cols.median())
print("\nMode:\n", num_cols.mode().iloc[0])

# ---------------------------
# Measures of Dispersion
# ---------------------------
print("\nMinimum:\n", num_cols.min())
print("\nMaximum:\n", num_cols.max())
print("\nSum:\n", num_cols.sum())
print("\nVariance:\n", num_cols.var())
print("\nStandard Deviation:\n", num_cols.std())

# ---------------------------
# Quartiles
# ---------------------------
print("\nQuartiles:")
print("Q1:\n", num_cols.quantile(0.25))
print("Q2 (Median):\n", num_cols.quantile(0.50))
print("Q3:\n", num_cols.quantile(0.75))

# ---------------------------
# Correlation
# ---------------------------
print("\nCorrelation Matrix:\n", num_cols.corr())

# ---------------------------
# Covariance
# ---------------------------
print("\nCovariance Matrix:\n", num_cols.cov())

# ---------------------------
# Histograms
# ---------------------------
num_cols.hist()
plt.suptitle("Histograms of Numerical Features")
plt.show()

# ---------------------------
# Boxplots
# ---------------------------
num_cols.plot(kind='box')
plt.title("Boxplot of Numerical Features")
plt.show()
# Out:
# First 5 Records:
#      Name  Age  Marks  Attendance  Study_Hours Department
# 0   Aman   20     85          90            4        CSE
# 1   Riya   21     90          85            5         IT
# 2  Rahul   19     78          80            3        CSE
# 3  Sneha   22     88          87            4        ECE
# 4   Amit   20     76          75            2         ME
#
# Data Types:
#  Name           object
# Age             int64
# Marks           int64
# Attendance      int64
# Study_Hours     int64
# Department     object
# dtype: object
#
# Numerical Columns:
#  Index(['Age', 'Marks', 'Attendance', 'Study_Hours'], dtype='object')
#
# Categorical Columns:
#  Index(['Name', 'Department'], dtype='object')
#
# Mean:
#  Age            20.5
# Marks          82.4
# Attendance     84.4
# Study_Hours     3.7
# dtype: float64
#
# Median:
#  Age            20.5
# Marks          83.0
# Attendance     86.0
# Study_Hours     3.5
# dtype: float64
#
# Mode:
#  Age            20.0
# ...
